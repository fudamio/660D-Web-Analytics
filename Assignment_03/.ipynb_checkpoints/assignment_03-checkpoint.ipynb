# %%
import pandas as pd
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline

nlp = spacy.load('en')
# %matplotlib inline

# %%
df = pd.read_json('reviews.json')
df.head()
# Out:
#            Date  Image                                             Review  \
# 0    2017-03-04      1  These Rockbirds LED Flashlights I bought came ...
# 1    2018-02-10      0  Given my many prior, poor experiences with sev...
# 10   2017-04-30      0  Really love these little flashlights, they're ...
# 100  2017-06-27      0                little rust inside and poor quality
# 1000 2018-04-09      0                         Great little bright light!
#
#                     Star             Status  \
# 0     5.0 out of 5 stars  Verified Purchase
# 1     4.0 out of 5 stars  Verified Purchase
# 10    4.0 out of 5 stars  Verified Purchase
# 100   1.0 out of 5 stars  Verified Purchase
# 1000  5.0 out of 5 stars  Verified Purchase
#
#                                                 Subject              author
# 0     Quality made and a fantastic deal!  Let me sho...           GardenGuy
# 1     Miniature in size & price, but big on light ou...                 NSB
# 10               Fantastic Little Flashlight, Except...  The Great Buzzwami
# 100                                            One Star                 Joe
# 1000                                         Five Stars               Laura

# %%
#extract star
df['Star'] = df['Star'].apply(lambda x: x.split(' ')[0])
#since every row represents a verified purchase just drop the column
df.drop('Status',inplace=True,axis=1)
#convert Star to numeric 
df.Star = pd.to_numeric(df.Star)
#convert Data to datetime and pick data after January 1st, 2017
df.Date = pd.to_datetime(df.Date)
df= df[df['Date'] > '2017-01-01']
#Extract the month of the reviews
df['month'] = pd.to_datetime(df.Date).dt.month
#Extract the day of the reviews
df['day'] = pd.to_datetime(df.Date).dt.day
df = df.reset_index(drop=True)

# %% [markdown]
# ## Star distribution
# - The mean star of all reviews are 4.2

# %%
plt.hist(df.Star)
plt.show()

# %%
df.Star.describe()
# Out:
# count    813.000000
# mean       4.211562
# std        1.298735
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# Name: Star, dtype: float64

# %% [markdown]
# ## Average stars per month
# - the plot of mean star for every month shows that the month may influence the star reviews made

# %%
df.groupby(['month']).Star.mean().plot(kind='line')

# %% [markdown]
# ### Let's count the number of reviews each reviewers made
# - Chris and Eric made 4 reviews and there are names like CJ and B which seems like a nickname let's check their reviews

# %%
df.groupby(['author']).Star.count().sort_values(ascending=False)[:20].plot(kind='bar')

# %%
df[df['author'].isin(['Chris','Eric','CJ'])]
# Out:
#           Date  Image                                             Review  \
# 24  2017-09-21      0                            Very bright and compact
# 105 2017-12-31      0  These are good to have everywhere, especially ...
# 218 2017-09-13      0  Bought before hurricane Irma. Wanted led flash...
# 365 2017-09-19      0  works good.  Love that it takes 1 AA and its p...
# 371 2018-03-04      0  Very bright flashlight.  Used at the beach wal...
# 389 2017-04-12      0  Pretty Good, Not as expected for any pinpoint ...
# 391 2017-08-29      0  These are amazingly good little flashlights.  ...
# 422 2018-02-13      0                                Small and powerful!
# 607 2017-06-27      0  Just received these today. So far so good, not...
# 665 2017-05-10      1  I got the 4 pack camping lights the other day....
#
#      Star                                            Subject author  month  \
# 24    5.0                                        Works great   Eric      9
# 105   5.0                        Handy with the clip on side     CJ     12
# 218   5.0  Bought before hurricane Irma. Wanted led flash...     CJ      9
# 365   5.0                                       Pretty good.   Eric      9
# 371   5.0                     Good flashlights for the price   Eric      3
# 389   4.0  Pretty Good, Not as expected for any pinpoint ...   Eric      4
# 391   5.0                                         Five Stars  Chris      8
# 422   5.0                                         Five Stars  Chris      2
# 607   2.0  So far so good, not super bright but not bad e...  Chris      6
# 665   5.0                 lightweight,good for group camping  Chris      5
#
#      day
# 24    21
# 105   31
# 218   13
# 365   19
# 371    4
# 389   12
# 391   29
# 422   13
# 607   27
# 665   10

# %% [markdown]
#  Seems everything goes well so we can't get much information from Author of the review

# %%
df.drop(['author','Date','day'],inplace=True,axis=1)

# %% [markdown]
# ###  Let's see if the length of the review will reflect the reviewer's attitute toward the item

# %%
df['Length_of_Review'] = df.Review.apply(lambda x: len(x))

# %%
df['Length_cat'] = np.ceil(df['Length_of_Review']/200)

# %%
df.groupby('Length_cat').Star.mean().plot(kind='line')

# %%
df['Length_cat'].value_counts()
# Out:
# 1.0     600
# 2.0     139
# 3.0      43
# 4.0      20
# 5.0       7
# 13.0      1
# 7.0       1
# 6.0       1
# 11.0      1
# Name: Length_cat, dtype: int64

# %%
np.corrcoef([df['Length_cat'],df['Star']])
# Out:
# array([[ 1.        , -0.04624103],
#        [-0.04624103,  1.        ]])

# %% [markdown]
# ### seems the length of the review does not correlate to the star, the gap in 6 of the Length_cat is because of the one single review so it's not representative.

# %%
df.drop(['Length_of_Review'],axis=1,inplace=True)

# %% [markdown]
# ## Sentiment Analysis
# - here we use nltk to process sentiment analysis to see if we can extract information from review's sentiment

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
ss = sid.polarity_scores(df.Review[0])

# %%
compound=[]
neg=[]
neu=[]
pos=[]
for i in range(len(df)):
    ss = sid.polarity_scores(df.Review[i])
    compound.append(ss['compound'])
    neg.append(ss['neg'])
    neu.append(ss['neu'])
    pos.append(ss['pos'])
df['Review_compund']=compound
df['Review_neg']=neg
df['Review_neu']=neu
df['Review_pos']=pos

# %%
compound=[]
neg=[]
neu=[]
pos=[]
for i in range(len(df)):
    ss = sid.polarity_scores(df.Subject[i])
    compound.append(ss['compound'])
    neg.append(ss['neg'])
    neu.append(ss['neu'])
    pos.append(ss['pos'])
df['Subject_compund']=compound
df['Subject_neg']=neg
df['Subject_neu']=neu
df['Subject_pos']=pos

# %%
corr = df[['Star','Image','month', 'Length_cat',
       'Review_compund', 'Review_neg', 'Review_neu', 'Review_pos',
       'Subject_compund', 'Subject_neg', 'Subject_neu', 'Subject_pos']].corr()
sns.set(style="white")
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)


sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Correlation Heatmap
# - from correlation heatmap we can see that review and subjects' sentiment will reflect the Star customer made

# %% [markdown]
# ## vectorize our reviews and subject
# - but first we want to lemmatize our sentence

# %%
def lemmatize(sentence):    
    doc = nlp(sentence)    
    preprocessed_sentences  = ' '.join([t.lemma_ for t in doc])
    preprocessed_sentences = preprocessed_sentences.replace('-PRON-' , '')
    preprocessed_sentences = preprocessed_sentences.replace('-pron-' , '')
    return preprocessed_sentences

# %%
df.Review = df.Review.apply(lemmatize)
df.Subject = df.Subject.apply(lemmatize)

# %%
# Out:
#      Image  Star  month  Length_cat  Review_compund  Review_neg  Review_neu  \
# 0        1   5.0      3         5.0          0.9667       0.010       0.859
# 1        0   4.0      2        11.0          0.9630       0.043       0.850
# 2        0   4.0      4         3.0          0.8812       0.028       0.865
# 3        0   1.0      6         1.0         -0.4767       0.383       0.617
# 4        0   5.0      4         1.0          0.7905       0.000       0.222
# 5        0   5.0      9         1.0          0.6249       0.000       0.328
# 6        0   2.0      6         2.0         -0.7691       0.181       0.740
# 7        0   5.0     10         1.0          0.9038       0.000       0.385
# 8        0   5.0      4         1.0          0.7670       0.000       0.312
# 9        0   5.0      4         2.0          0.9589       0.000       0.699
# 10       0   5.0      4         1.0          0.9231       0.000       0.231
# 11       0   3.0      8         1.0          0.6124       0.000       0.444
# 12       0   5.0      4         1.0          0.6114       0.000       0.501
# 13       0   5.0     10         1.0          0.7732       0.000       0.572
# 14       0   2.0      5         5.0          0.2321       0.045       0.896
# 15       0   5.0      6         1.0          0.6588       0.000       0.406
# 16       0   5.0      5         2.0          0.9682       0.000       0.747
# 17       0   3.0      2         1.0          0.4404       0.000       0.873
# 18       0   5.0      4         1.0          0.0000       0.000       1.000
# 19       0   5.0      9         1.0          0.8615       0.000       0.239
# 20       0   5.0      1         3.0          0.9687       0.014       0.774
# 21       0   5.0     10         1.0          0.5719       0.000       0.000
# 22       0   5.0      3         1.0          0.9216       0.042       0.607
# 23       0   5.0      4         1.0          0.8122       0.000       0.351
# 24       0   5.0      9         1.0          0.4927       0.000       0.484
# 25       0   5.0      4         1.0          0.6249       0.000       0.196
# 26       0   5.0      7         1.0          0.6249       0.000       0.000
# 27       0   4.0      9         1.0          0.8107       0.000       0.404
# 28       0   5.0      5         2.0          0.9359       0.000       0.788
# 29       0   5.0      9         1.0          0.7003       0.000       0.580
# ..     ...   ...    ...         ...             ...         ...         ...
# 783      0   5.0     11         1.0          0.6115       0.172       0.328
# 784      0   4.0      9         1.0          0.4927       0.000       0.803
# 785      1   4.0      9         2.0          0.9412       0.000       0.780
# 786      0   2.0      5         1.0         -0.3178       0.272       0.576
# 787      0   5.0     10         1.0          0.7783       0.000       0.370
# 788      0   5.0      9         1.0          0.8070       0.000       0.490
# 789      0   5.0      5         1.0          0.9071       0.000       0.531
# 790      0   2.0     10         1.0         -0.2334       0.278       0.722
# 791      0   5.0      5         1.0          0.6249       0.000       0.631
# 792      0   4.0      5         2.0          0.9451       0.000       0.693
# 793      0   5.0      2         1.0          0.0000       0.000       1.000
# 794      0   4.0      3         1.0          0.0000       0.000       1.000
# 795      0   2.0      4         1.0          0.2023       0.000       0.847
# 796      0   5.0      4         1.0         -0.1027       0.085       0.915
# 797      0   5.0      6         1.0          0.8248       0.000       0.675
# 798      0   1.0      2         1.0         -0.8080       0.291       0.581
# 799      0   4.0      1         4.0          0.8884       0.024       0.858
# 800      0   5.0      4         1.0          0.4927       0.000       0.556
# 801      0   5.0      5         1.0          0.8588       0.000       0.485
# 802      0   1.0      4         1.0         -0.3400       0.194       0.806
# 803      0   5.0      7         2.0          0.8885       0.000       0.830
# 804      0   2.0      5         1.0         -0.7425       0.215       0.785
# 805      0   1.0      4         1.0         -0.4215       0.219       0.781
# 806      0   5.0     10         1.0          0.4215       0.000       0.588
# 807      0   5.0      6         1.0          0.5859       0.000       0.759
# 808      0   3.0      4         1.0          0.0000       0.000       1.000
# 809      0   4.0      4         1.0          0.8217       0.000       0.613
# 810      0   5.0      8         1.0          0.6588       0.000       0.406
# 811      0   5.0      4         1.0          0.4404       0.000       0.756
# 812      0   5.0      9         1.0          0.5719       0.000       0.213
#
#      Review_pos  Subject_compund  Subject_neg  Subject_neu  Subject_pos
# 0         0.131           0.5983        0.000        0.739        0.261
# 1         0.107           0.0000        0.000        1.000        0.000
# 2         0.107           0.5574        0.000        0.455        0.545
# 3         0.000           0.0000        0.000        1.000        0.000
# 4         0.778           0.0000        0.000        1.000        0.000
# 5         0.672           0.1531        0.000        0.556        0.444
# 6         0.079          -0.3412        0.445        0.555        0.000
# 7         0.615           0.0000        0.000        1.000        0.000
# 8         0.688           0.0000        0.000        1.000        0.000
# 9         0.301           0.5719        0.000        0.764        0.236
# 10        0.769           0.0000        0.000        1.000        0.000
# 11        0.556           0.4404        0.000        0.508        0.492
# 12        0.499           0.0000        0.000        1.000        0.000
# 13        0.428           0.6249        0.000        0.328        0.672
# 14        0.059           0.6041        0.000        0.753        0.247
# 15        0.594           0.0000        0.000        1.000        0.000
# 16        0.253           0.6124        0.000        0.375        0.625
# 17        0.127           0.0000        0.000        1.000        0.000
# 18        0.000           0.0000        0.000        1.000        0.000
# 19        0.761           0.0000        0.000        1.000        0.000
# 20        0.212           0.7519        0.000        0.356        0.644
# 21        1.000           0.0000        0.000        1.000        0.000
# 22        0.351           0.8011        0.000        0.582        0.418
# 23        0.649           0.0000        0.000        1.000        0.000
# 24        0.516           0.6249        0.000        0.196        0.804
# 25        0.804           0.0000        0.000        1.000        0.000
# 26        1.000           0.0000        0.000        1.000        0.000
# 27        0.596           0.8107        0.000        0.404        0.596
# 28        0.212           0.7783        0.000        0.306        0.694
# 29        0.420           0.0000        0.000        1.000        0.000
# ..          ...              ...          ...          ...          ...
# 783       0.500           0.0000        0.000        1.000        0.000
# 784       0.197           0.0000        0.000        1.000        0.000
# 785       0.220           0.6249        0.000        0.631        0.369
# 786       0.152          -0.4585        0.750        0.250        0.000
# 787       0.630           0.0000        0.000        1.000        0.000
# 788       0.510           0.0000        0.000        1.000        0.000
# 789       0.469           0.0000        0.000        1.000        0.000
# 790       0.000           0.0000        0.000        1.000        0.000
# 791       0.369           0.0000        0.000        1.000        0.000
# 792       0.307           0.7003        0.000        0.256        0.744
# 793       0.000           0.0000        0.000        1.000        0.000
# 794       0.000           0.0000        0.000        1.000        0.000
# 795       0.153           0.2023        0.000        0.795        0.205
# 796       0.000          -0.1027        0.135        0.865        0.000
# 797       0.325           0.6113        0.000        0.643        0.357
# 798       0.127          -0.5267        0.815        0.185        0.000
# 799       0.117           0.8910        0.000        0.398        0.602
# 800       0.444           0.0000        0.000        1.000        0.000
# 801       0.515           0.0000        0.000        1.000        0.000
# 802       0.000           0.0000        0.000        1.000        0.000
# 803       0.170           0.5719        0.000        0.575        0.425
# 804       0.000          -0.5256        0.404        0.596        0.000
# 805       0.000           0.0000        0.000        1.000        0.000
# 806       0.412           0.0000        0.000        1.000        0.000
# 807       0.241           0.0000        0.000        1.000        0.000
# 808       0.000           0.0000        0.000        1.000        0.000
# 809       0.387           0.6249        0.000        0.328        0.672
# 810       0.594           0.0000        0.000        1.000        0.000
# 811       0.244           0.0000        0.000        1.000        0.000
# 812       0.787           0.4404        0.000        0.256        0.744
#
# [813 rows x 12 columns]

# %% [markdown]
# ### Now we can use TF-IDF algorithm to vectorize our reviews and subject

# %%
class Vectorizer(BaseEstimator, TransformerMixin):
    def __init__(self,max_df=1,min_df=0,ngram_range=(1,2)):
        self.max_df = max_df
        self.min_df = min_df
        self.ngram_range =ngram_range
        
    def fit(self, X, y=None):
        return self
        
    def transform(self, X):
        vectorizer = TfidfVectorizer(ngram_range=self.ngram_range,stop_words='english',max_df=self.max_df,min_df=self.min_df)
        review_vector = vectorizer.fit_transform(X['Review'])
        subject_vector = vectorizer.fit_transform(X['Subject'])
        vec_df = pd.concat([pd.DataFrame(review_vector.toarray()),pd.DataFrame(subject_vector.toarray())],axis=1)
        vec_df = pd.concat([vec_df,df.drop(['Review','Subject'],axis=1)],axis=1)
        vec_df = vec_df.fillna(0)
    
        return vec_df

# %%
label = df.Star
data= df.drop('Star',axis=1)

# %% [markdown]
# ### Let's train our model

# %%
vec = Vectorizer()
pre_process_data = vec.fit_transform(data)
#first vectorize our review and subject
rf = RandomForestClassifier()
cross_val_score(rf, X=pre_process_data, y=label, cv=10,scoring='accuracy').mean()
# Out:
# 0.85132684385788482

# %% [markdown]
# ### Using RandomForestClassifier the mean accuracy of 10 fold cross validation is 85.13%

# %% [markdown]
# ### Data Augmentation
# Since it's an unbalanced dataset we can use RandomOverSampler to generate new samples in the classes which are under-represented

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=0)
X_resampled, y_resampled = ros.fit_sample(pre_process_data, label)
cross_val_score(rf, X=X_resampled, y=y_resampled, cv=10).mean()
# Out:
# 0.99772859216255438

# %% [markdown]
# #### after data augmentation the mean accuracy of 10 fold cross validation is 99.77%
